# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Вычислить вершину
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %%
from numpy import linspace, sin, cos
import matplotlib.pyplot as plt
#)  - 18*x**3+5*x**2 + 10*x - 30
x=linspace(-1000, 1000, 400)

y = -12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30
f=plt.plot(x,y)
plt.show()

# %% [markdown]
# 1. Функция имеет бесконечное множество корней и чем ближе к нулю по оси абсцисс тем они чаще
# 2. Функция имеет бесконечное множество интервалов возрастания и убывания, и чем дальше от нуля по оси абсцисс тем они продолжительнее.
# 3. Функция имеет бесконечное множество вершин и чем ближе к нулю по оси абсцисс тем они чаще
# 4. У функции бесконечное множество промежутков где она принимает значения больше нуля и меньше нуля, чем дальше от нуля по оси абсцисс тем они продолжительнее.
